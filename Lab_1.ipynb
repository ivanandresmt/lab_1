# %% [markdown]
# <h1><center>Laboratorio 1: Git 👾</center></h1>
#
# <center><strong>MDS7202: Laboratorio de Programación Científica para Ciencia de Datos - Otoño 2023</strong></center>

# %% [markdown]
# ### Cuerpo Docente:
#
# - Profesores: Pablo Badilla, Ignacio Meza D.
# - Auxiliar: Sebastián Tinoco
# - Ayudante: Diego Cortez

# %% [markdown]
# ### Equipo: SUPER IMPORTANTE - notebooks sin nombre no serán revisados
#
# - Nombre de alumno 1: Iván Meneses
# - Nombre de alumno 2: Sofía Callejas

# %% [markdown]
# ### **Link de repositorio de GitHub:** https://github.com/ivanandresmt/lab_1.git

# %% [markdown]
# ## Reglas:
#
# - Fecha de entrega: 6 días desde la publicación, 3 días de atraso con 1 punto de descuento c/u. Pueden utilizar días bonus sin descuento.
# - **Grupos de 2 personas**.
# - **Ausentes** deberán realizar la actividad solos.
# - Cualquier duda fuera del horario de clases al foro. Mensajes al equipo docente serán respondidos por este medio.
# - <u>Prohibidas las copias</u>. Cualquier intento de copia será debidamente penalizado con el reglamento de la escuela.
# - Pueden usar cualquer material del curso que estimen conveniente.
# - Asistencia obligatoria a instrucciones del lab (viernes 16.15). Luego, pueden quedarse trabajando en las salas o irse.

# %% [markdown]
# ## Objetivos del lab:
#
#
# - Conocer los elementos básicos que conformar `Git`
# - Clonar repositorios
# - Identificar ramas de un repositorio
# - Reconocer y solucionar problemas entre ramas
# - Subir cambios a un repositorio

# %% [markdown]
# ## Parte 1: Conocimiento Teórico (2 pts)

# %% [markdown]
# Responda las siguientes preguntas (0.2 pts c/u):
#
# 1. ¿Qué es `Git` y cómo se relaciona con el control de versiones?
#
# Git es un DVSC y se relaciona directamente dado que un VSC es un control de versiones es un sistema que registra los
# cambios realizados en un archivo o conjunto de
# archivos a lo largo del tiempo
#
# 2. Nombre y explique 3 diferencias entre `Git` y `Github`.
#
# Git es un sistema de control de versiones distribuido, en cambio github es un espacio para subir una
# copia de los repositorios de Git.
#
# Git es un software, por otro lado github es un servicio de alojamiento
# basado en web
#
# Git es una herramienta de linea de
# comando, por otro lado github entrega una interfaz grafica
#
#
#
# 3. ¿Qué es un `hash` y cómo se representa en un `commit`? De un ejemplo.
#
# El  nombre de hash se usa para identificar una función criptográfica muy importante en el mundo informático. Estas funciones tienen como objetivo primordial codificar datos para formar una cadena de caracteres única.
#
# En Git un commit tiene 40 caracteres, para registrarlos, como por ejemplo: 4387hgnjk389hnj49nhj3847nnvg909035nngjd9
#
# 4. ¿Que elementos componen a la estructura de datos de `Git`?
#
# Esta compuesto por:
# - blob
# - tree
# - commit
#
# 5. ¿Que comandos de `Git` sirven para crear un repositorio y hacer seguimiento a cambios en los archivos?
#
#  git init nombre-del-repo, es para crear el nombre del repositorio
#
#  git log,, para hacer el seguimiento a cambios en los archivos

# %% [markdown]
# Responda si las siguientes afirmaciones son Verdaderas (V) o Falsas (F). Justifique en **cualquiera** de los casos (0.2 pts c/u):
#
#
# 6. `Git` siempre resuelve automáticamente los problemas de lineas al hacer merge entre diferentes ramas.
#
# F, hay que hacerlo a mano.
#
# 7. Ejecutar `git pull` sobre un repositorio es equivalente a ejecutar `git clone`.
#
# F, no es lo mismo dado que git pull se obtiene el registro de cambios de un repositorio remoto y git clone permite clonar un repositorio remoto.
#
# 8. Cada miembro del equipo trabaja en la misma copia del código fuente usando `Git`.
#
# F, se pueden trabajar distintas versiones al mismo tiempo.
#
# 9. En `Git` es posible deshacer cambios y volver a versiones anteriores del código.
#
# V
#
# 10. El comando `git commit` se utiliza para enviar cambios al repositorio remoto.
#
# V

# %% [markdown]
# ## Parte 2: Creando una presentación personal (2 pts)

# %% [markdown]
# Para empezar a "*soltar las manos*" con `Git`, se les encomienda crear un repositorio con una presentación personal. El repositorio debe contener un breve resumen de quienes son ustedes, sus gustos, experiencias, y cualquier otro detalle interesante que ustedes consideren relevante.
#
# Para realizar esto, deben seguir los siguientes pasos:
#
# 1. Contar con una cuenta de github (1 por persona)
# 2. Crear un repositorio con su nombre de usuario
# 3. Crear y modificar un archivo `readme.md` con la información que ustedes deseen compartir.
#
# A modo de ejemplo, pueden guiarse por esta *suculenta* [presentación](https://github.com/pbadillatorrealba/pbadillatorrealba).
#
# *Hint: Una buena opción es usar templates de presentación personal que encuentren en Google, como los que ofrece este [sitio](https://durgeshsamariya.github.io/awesome-github-profile-readme-templates/#/)*.
#
# **Entregable:**
#
# Enlace al repositorio con la presentación personal.
#
# IMPORTANTE: DEBEN ADJUNTAR UN ENLACE POR PERSONA

# %% [markdown]
# <code>Link Presentacion 1: https://github.com/sofia-callejas/sofia-callejas</code>
#
# <code>Link Presentacion 2: https://github.com/ivanandresmt/ivanandresmt.git</code>

# %% [markdown]
# ## Parte 3: Trabajando sobre un repositorio externo (2 pts)

# %% [markdown]
# Tras muchos dolores de cabeza, un grupo de entusiastas académicos decidieron aprender sobre `Git` y así trabajar colaborativamente de forma más ordenada y eficiente. Después de una infinidad de intentos y aprender de sus errores "*a la mala*", los académicos lograron levantar un [repositorio](https://github.com/MDS7202/lab1) en `Github`. Usando el repositorio de los académicos, responda las siguientes preguntas (incluya también los comandos en `Git` ocupados):

# %% [markdown]
# 1. Clone el repositorio a su ambiente local. (0.25 pts)
#
# Se clona el repositorio mediante el comando "git clone + direccion del repositorio" usando la consola de VSC:
#
#
# ![p1_lab1.png](data:image/png;base64,...)

# %% [markdown]
# 2. Inspeccione brevemente el repositorio: ¿Cual es el objetivo del proyecto? Explique brevemente la estructura del proyecto, asi como también de cada componente que lo conforma. (0.25 pts)

# %% [markdown]
#      El objetivo del proyecto es entregar información acerca del sonido que hacen ciertos animales, ya sea, de forma escrita; para el caso del gato y el perro, ó en forma audiovisual para el caso del zorro mediante un enlace a YouTube.
#       La estructura del proyecto se compone de 3 archivos, 2 de ellos son de tipo ".py" que contienen el código del programa, y un archivo tipo markdown ".md" que contiene la imagen de animales que, por cierto, NO contienen ninguno de los animales que reconoce el programa.
#       En el archivo 'animales.py' se define la función "animales" que recibe como input el nombre de cualquier animal y evalua mediante condiciones "if" si al pasar dicho nombre (input) a minusculas es igual a un gato, perro o fox. En caso de no cumplirse ninguna de estas 3 condiciones la función retorna que el animal no es reconocido.
#       Para el caso del archivo 'main.py' contiene el programa que, al ejecutarse pregunta por el animalito para saber que dice, ya que, usa del archivo 'animales.py' la funcion "animales". Una vez que se inserta el nombre del animal que se desea conocer su sonido, este programa retorna dicho sonido si encuentra en sus datos, y si no es posible, entonces dice que el animal no es reconocido.

# %% [markdown]
# 3. Identifique los últimos cambios al repositorio, reconociendo las principales ramas de trabajo. ¿Son informativos los `commit` realizados? (0.25 pts)
# *Hint: Se recomienda usar los argumentos `all`, `graph` y `decorate`*

# %% [markdown]
# Para consultar los últimos commits realizados en el repositorio se utiliza el comando "git log --decorate --graph --all" que entrega un registro de los cambios en orden temporal y además indicando sus respectivas ramas. Se puede apreciar que los commits son informativos, ya que, a través de los comentarios (mensajes) es posible saber de que tratan cada uno:
#
# ![p3.png](data:image/png;base64,...)

# %% [markdown]
# 4. Uno de los académicos se da cuenta que la rama principal de trabajo no se ejecuta correctamente para todos los argumentos. Señale el error en el código e identifique a la persona que lo cometió usando `git blame` (0.25 pts)
#
# *Hint: Le puede ser útil esta [documentación](https://www.atlassian.com/es/git/tutorials/inspecting-a-repository/git-blame).*

# %% [markdown]
# La rama principal "main.py" no contiene errores de código explícitos, sin embargo, no se ejecuta correctamente para todos los argumentos, ya que, usa la función "animales" del archivo "animales.py" que tampoco contiene errores de código explícitos, pero sí contiene errores implícitos en las condiciones, ya que, debería llevar "elif" anidados en vez de "if", porque al ejecutar la función con "if" esta evalua todas las condiciones sin importar si ya se ha cumplido antes alguna condición, entonces, esto significa que a pesar de haber encontrado alguna coincidencia con los valores, arrojará al final el sonido del animal y también un error por no haber encontrado coincidencias, lo que resulta contradictorio.
#
# Para conocer al "culpable" de este error usamos el comando "git blame animales.py -e" y vimos que la persona que escribió las líneas de código en que se encuentran las condiciones "if" fue Ignacio Meza.
#
# ![blame.png](data:image/png;base64,...)

# %% [markdown]
# 5. Busque los siguientes `commit`:
#
# - `c8b1a62d7299552b0654f930d695b33109214111`
# - `362fe21ee44f53ee944cee4ba484600308f83d78`
# - `25543a3baf77292baf849726784ca005473acab1`
#
# ¿Qué diferencias existen entre cada uno? (0.25 pts)

# %% [markdown]
# En el primer commit (c8b1a62d7299552b0654f930d695b33109214111) se grega la función animales al proyecto, y en el segundo commit (362fe21ee44f53ee944cee4ba484600308f83d78) se separa el proyecto en módulos, donde se toma la función del primer commit y se traslada a un nuevo archivo por medio de la separación en ramas "new_feautures" y "main". Por último, en el tercer commit (25543a3baf77292baf849726784ca005473acab1) se agrega la rama "fix ifs" que contiene la reparación del código para la función "animales".
#
#
# ![m4.png](data:image/png;base64,...)

# %% [markdown]
# 6. Realice una `merge` de la rama `fix-ifs` con la rama `main` y describa lo que ocurre. ¿Qué parte del código podría estar ocasionando esto? (0.25 pts)

# %% [markdown]
# Al hacer el merge entre la rama "main" y "fix-ifs" mediante el comando "git merge origin/fix-ifs" ocurre un conflicto, ya que, hay distintos cambios para el mismo archivo "main.py".
#
# ![conflicto.png](data:image/png;base64,...)
#
# La parte del código que ocasiona el problema es la parte referente a la función "animales", ya que, compromete errores en las condiciones "if" y estas se modifican por "elif" en la modificación entrante:
#
# ![codigo error.png](data:image/png;base64,...)

# %% [markdown]
# 7. Cree una rama nueva y proponga una solución al problema anterior, adjuntando el código corregido y señalando las líneas modificadas. (0.5 pts)

# %% [markdown]
# Se crea la rama "rama_salvadora" que contiene los cambios a la función "animales" (se cambia if por elif en segunda y tercera condición), luego se hace el "merge" con la rama "main" y se actualizan los cambios quedando el código sin errores:
#
# ![ramanueva.png](data:image/png;base64,...)

# %% [markdown]
# ## Fin

# %% [markdown]
# Eso ha sido todo por ahora!! Esperamos que este laboratorio les haya gustado y servido para trabajar con `Git`. Recuerden los dias de plazo que tienen disponibles y que ante cualquier duda no duden en contactar al equipo docente.
#
# Nos vemos!!
#
# <img src=https://media.tenor.com/OYLdav9k9LkAAAAd/kitty-cat.gif height=300>
